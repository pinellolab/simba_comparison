# %%
# %load_ext nb_black

import clustering_evaluator as clust_eval

# %%
DataDict = clust_eval.load_data(path="/Users/mvinyard/Desktop/simba_data/")
# Out:
# buenrostro2018.peaks           | celltypes: 10 | dataset: buenrostro2018 | features: ['peaks']
# BMsim_clean.peaks              | celltypes: 6  | dataset: BMsim_clean    | features: ['peaks']
# BMsim_noisyp4.peaks_sequences  | celltypes: 6  | dataset: BMsim_noisyp4  | features: ['peaks', 'sequences']
# buenrostro2018.peaks_sequences | celltypes: 10 | dataset: buenrostro2018 | features: ['peaks', 'sequences']
# BMsim_clean.peaks_sequences    | celltypes: 6  | dataset: BMsim_clean    | features: ['peaks', 'sequences']
# sciatac_subset.peaks_sequences | celltypes: 13 | dataset: sciatac_subset | features: ['peaks', 'sequences']
# 10xpbmc_5k.peaks_sequences     | celltypes: 8  | dataset: 10xpbmc_5k     | features: ['peaks', 'sequences']
# 10xpbmc_5k.peaks               | celltypes: 8  | dataset: 10xpbmc_5k     | features: ['peaks']
# BMsim_noisyp4.peaks            | celltypes: 6  | dataset: BMsim_noisyp4  | features: ['peaks']
# ...

# %%
clust_eval.evaluate_embedding(
    DataDict,
    random_state=2022,
)
# Out:
# 100%|█████████████| 10/10 [00:39<00:00,  3.92s/it]

# %%
clust_eval.plot_metrics(
    DataDict, save=True, savename="clustering_metrics.feature_comparison_overview.svg"
)
score_df = clust_eval.format_clustering_scores(DataDict)

# %%
clust_eval.compare_features_plot(
    score_df,
    save=True,
    savename="clustering_metrics.feature_comparison.svg",
)
