# %%
# %load_ext nb_black

import performance_benchmark as pb
import matplotlib.pyplot as plt
# Out:
# GPUTrainingCoordinator: GPU INSTALLED
# Available memory: 491 Gb
# Available vCPUs: 24

# %%
for n_cells in [500, 1000, 2500, 5000, 10000, 25000, 50000, 100000, 250000, 500000]:
    print("# cells: {}".format(n_cells))
    plot = pb.results.PlotTimeMemory(
        results_path="./results/mouse_neurons.downsample_{}cells/".format(n_cells),
        save=True,
        savename="./figs/compare_all_methods.time_memory.mouse_neurons_downsampled.{}_cells.svg".format(
            n_cells
        ),
        figsize=0.25,
        legend_loc=(3.5, 0.25),
        wspace=0.5,
    )
    plt.show()
# Out:
# # cells: 500
# # cells: 1000
# # cells: 2500
# # cells: 5000
# # cells: 10000
# # cells: 25000
# # cells: 50000
# # cells: 100000
# # cells: 250000
# # cells: 500000
