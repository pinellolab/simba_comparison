# %%
# %load_ext nb_black

import performance_benchmark as pb
# Out:
# GPUTrainingCoordinator: GPU INSTALLED
# Available memory: 9 Gb
# Available vCPUs: 2

# %%
plot = pb.results.PlotTimeMemory(
    results_path="./results/mouse_neurons.downsample_500cells/",
    save=True,
    savename="./figs/compare_all_methods.time_memory.mouse_neurons_downsampled.500_cells.svg",
    figsize=0.25,
    legend_loc=(3.5, 0.25),
    wspace=0.5,
)

# %%
plot = pb.results.PlotTimeMemory(
    results_path="./results/mouse_neurons.downsample_100000cells/",
    save=True,
    savename="./figs/compare_all_methods.time_memory.mouse_neurons_downsampled.100k_cells.svg",
    figsize=0.25,
    legend_loc=(3.5, 0.25),
    wspace=0.5,
)

# %%
plot = pb.results.PlotTimeMemory(
    results_path="./results/mouse_neurons.downsample_500000cells/",
    save=True,
    savename="./figs/compare_all_methods.time_memory.mouse_neurons_downsampled.500k_cells.svg",
    figsize=0.25,
    legend_loc=(3.5, 0.25),
    wspace=0.5,
)
