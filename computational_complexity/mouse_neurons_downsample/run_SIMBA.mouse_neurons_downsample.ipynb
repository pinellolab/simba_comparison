# %%
import performance_benchmark as pb
# Out:
# Available memory: 393 Gb
# Available vCPUs: 24

# %%
adata = pb.data.read_1M_neurons()
# Out:
# /home/mvinyard/.anaconda3/envs/simba_dev/lib/python3.9/site-packages/anndata/_core/anndata.py:1830: UserWarning: Variable names are not unique. To make them unique, call `.var_names_make_unique`.
#   utils.warn_names_duplicates("var")
# AnnData object with n_obs × n_vars = 1306127 × 27998
#     obs: 'Cluster'
#     var: 'gene_ids'

# %%
N_cells = [
    500,
    1_000,
    2_500,
    5_000,
    10_000,
    25_000,
    50_000,
    100_000,
    250_000,
    500_000,
    1_000_000,
    None,
]

# %%
for n in N_cells:
    print(n)
    if n:
        adata_downsample = pb.data.downsample(adata, n=n, random_state=617)
        n_cells = n
    else:
        adata_downsample = adata
        n_cells = 1306127
        
    simba_outs = pb.methods.simba(
        adata_downsample, n_iters=4, dataset="mouse_neurons_downsample.{}cells".format(n_cells)
    )
# Out:
# 500
# AnnData object with n_obs × n_vars = 500 × 27998
#     obs: 'Cluster'
#     var: 'gene_ids'
#   0%|          | 0/4 [00:00<?, ?it/s]
# Before filtering:
# 500 cells, 27998 genes
# Filter genes based on min_n_cells
# After filtering out low-expressed genes:
# 500 cells, 12798 genes
# before filtering:
# 500 cells,  12798 genes
# filter cells based on min_n_genes
# after filtering out low-quality cells:
# 497 cells,  12798 genes
# 2000 variable genes are selected.
# relation0: source: C, destination: G
# #edges: 45833
# relation1: source: C, destination: G
# #edges: 46041
# relation2: source: C, destination: G
# #edges: 27578
# relation3: source: C, destination: G
# #edges: 13560
# relation4: source: C, destination: G
# #edges: 6208
# Total number of edges: 139220
# Writing graph file "pbg_graph.txt" to "./result_simba/pbg/mouse_neurons_downsample.500cells" ...
# **EDGE WRITE TIME: 1.607**
# Finished.
# Auto-estimated weight decay is 0.254526
# `.settings.pbg_params['wd']` has been updated to 0.254526
# Converting input data ...
# [2022-11-28 01:52:56.468846] Using the 5 relation types given in the config
# [2022-11-28 01:52:56.470158] Searching for the entities in the edge files...
# [2022-11-28 01:52:57.627411] Entity type C:
# [2022-11-28 01:52:57.629035] - Found 497 entities
# [2022-11-28 01:52:57.630231] - Removing the ones with fewer than 1 occurrences...
# [2022-11-28 01:52:57.631438] - Left with 497 entities
# [2022-11-28 01:52:57.633514] - Shuffling them...
# [2022-11-28 01:52:57.636472] Entity type G:
# [2022-11-28 01:52:57.637569] - Found 2000 entities
# [2022-11-28 01:52:57.638439] - Removing the ones with fewer than 1 occurrences...
# [2022-11-28 01:52:57.639781] - Left with 2000 entities
# [2022-11-28 01:52:57.640811] - Shuffling them...
# [2022-11-28 01:52:57.655495] Preparing counts and dictionaries for entities and relation types:
# [2022-11-28 01:52:57.657670] - Writing count of entity type C and partition 0
# [2022-11-28 01:52:57.661243] - Writing count of entity type G and partition 0
# [2022-11-28 01:52:57.669239] Preparing edge path ./result_simba/pbg/mouse_neurons_downsample.500cells/input/edge, out of the edges found in result_simba/pbg/mouse_neurons_downsample.500cells/pbg_graph.txt
# using fast version
# [2022-11-28 01:52:57.671038] Taking the fast train!
# [2022-11-28 01:53:01.004583] - Processed 100000 edges so far...
# [2022-11-28 01:53:02.987536] - Processed 139220 edges in total
# Starting training ...
# Finished
# Performing softmax transformation for query data 0;
# Successfully saved to: ./simba_benchmark_results/mouse_neurons_downsample.500cells/benchmark_results.pkl
# Total size (bytes): 2238
#  - Removed graph dir: /home/mvinyard/SIMBA/tmp_run/./result_simba/pbg/mouse_neurons_downsample.500cells
# Before filtering:
# 500 cells, 27998 genes
# Filter genes based on min_n_cells
# After filtering out low-expressed genes:
# 500 cells, 12798 genes
# before filtering:
# 500 cells,  12798 genes
# filter cells based on min_n_genes
# after filtering out low-quality cells:
# 497 cells,  12798 genes
# 2000 variable genes are selected.
# relation0: source: C, destination: G
# #edges: 45833
# relation1: source: C, destination: G
# #edges: 46041
# relation2: source: C, destination: G
# #edges: 27578
# relation3: source: C, destination: G
# #edges: 13560
# relation4: source: C, destination: G
# #edges: 6208
# Total number of edges: 139220
# Writing graph file "pbg_graph.txt" to "./result_simba/pbg/mouse_neurons_downsample.500cells" ...
# **EDGE WRITE TIME: 1.975**
# Finished.
# Auto-estimated weight decay is 0.254526
# `.settings.pbg_params['wd']` has been updated to 0.254526
# Converting input data ...
# [2022-11-28 01:54:04.926726] Using the 5 relation types given in the config
# [2022-11-28 01:54:04.928096] Searching for the entities in the edge files...
# [2022-11-28 01:54:06.011316] Entity type C:
# [2022-11-28 01:54:06.012768] - Found 497 entities
# [2022-11-28 01:54:06.013697] - Removing the ones with fewer than 1 occurrences...
# [2022-11-28 01:54:06.014811] - Left with 497 entities
# [2022-11-28 01:54:06.015630] - Shuffling them...
# [2022-11-28 01:54:06.018109] Entity type G:
# [2022-11-28 01:54:06.019122] - Found 2000 entities
# [2022-11-28 01:54:06.020027] - Removing the ones with fewer than 1 occurrences...
# [2022-11-28 01:54:06.021312] - Left with 2000 entities
# [2022-11-28 01:54:06.022215] - Shuffling them...
# [2022-11-28 01:54:06.036757] Preparing counts and dictionaries for entities and relation types:
# [2022-11-28 01:54:06.038598] - Writing count of entity type C and partition 0
# [2022-11-28 01:54:06.041788] - Writing count of entity type G and partition 0
# [2022-11-28 01:54:06.048766] Preparing edge path ./result_simba/pbg/mouse_neurons_downsample.500cells/input/edge, out of the edges found in result_simba/pbg/mouse_neurons_downsample.500cells/pbg_graph.txt
# using fast version
# [2022-11-28 01:54:06.050112] Taking the fast train!
# [2022-11-28 01:54:08.438595] - Processed 100000 edges so far...
# [2022-11-28 01:54:10.087517] - Processed 139220 edges in total
# Starting training ...
# Finished
# Performing softmax transformation for query data 0;
# Successfully saved to: ./simba_benchmark_results/mouse_neurons_downsample.500cells_1/benchmark_results.pkl
# Total size (bytes): 2238
#  - Removed graph dir: /home/mvinyard/SIMBA/tmp_run/./result_simba/pbg/mouse_neurons_downsample.500cells
# Before filtering:
# 500 cells, 27998 genes
# Filter genes based on min_n_cells
# After filtering out low-expressed genes:
# 500 cells, 12798 genes
# before filtering:
# 500 cells,  12798 genes
# filter cells based on min_n_genes
# after filtering out low-quality cells:
# 497 cells,  12798 genes
# 2000 variable genes are selected.
# relation0: source: C, destination: G
# #edges: 45833
# relation1: source: C, destination: G
# #edges: 46041
# relation2: source: C, destination: G
# #edges: 27578
# relation3: source: C, destination: G
# #edges: 13560
# relation4: source: C, destination: G
# #edges: 6208
# Total number of edges: 139220
# Writing graph file "pbg_graph.txt" to "./result_simba/pbg/mouse_neurons_downsample.500cells" ...
# **EDGE WRITE TIME: 1.946**
# Finished.
# Auto-estimated weight decay is 0.254526
# `.settings.pbg_params['wd']` has been updated to 0.254526
# Converting input data ...
# [2022-11-28 01:54:47.530171] Using the 5 relation types given in the config
# [2022-11-28 01:54:47.531559] Searching for the entities in the edge files...
# [2022-11-28 01:54:48.634636] Entity type C:
# [2022-11-28 01:54:48.635906] - Found 497 entities
# [2022-11-28 01:54:48.636749] - Removing the ones with fewer than 1 occurrences...
# [2022-11-28 01:54:48.637861] - Left with 497 entities
# [2022-11-28 01:54:48.638720] - Shuffling them...
# [2022-11-28 01:54:48.641346] Entity type G:
# [2022-11-28 01:54:48.642237] - Found 2000 entities
# [2022-11-28 01:54:48.642939] - Removing the ones with fewer than 1 occurrences...
# [2022-11-28 01:54:48.644458] - Left with 2000 entities
# [2022-11-28 01:54:48.645289] - Shuffling them...
# [2022-11-28 01:54:48.660020] Preparing counts and dictionaries for entities and relation types:
# [2022-11-28 01:54:48.661637] - Writing count of entity type C and partition 0
# [2022-11-28 01:54:48.664799] - Writing count of entity type G and partition 0
# [2022-11-28 01:54:48.671999] Preparing edge path ./result_simba/pbg/mouse_neurons_downsample.500cells/input/edge, out of the edges found in result_simba/pbg/mouse_neurons_downsample.500cells/pbg_graph.txt
# using fast version
# [2022-11-28 01:54:48.672993] Taking the fast train!
# [2022-11-28 01:54:51.978255] - Processed 100000 edges so far...
# [2022-11-28 01:54:54.681586] - Processed 139220 edges in total
# Starting training ...
# Finished
# Performing softmax transformation for query data 0;
# Successfully saved to: ./simba_benchmark_results/mouse_neurons_downsample.500cells_2/benchmark_results.pkl
# Total size (bytes): 2238
#  - Removed graph dir: /home/mvinyard/SIMBA/tmp_run/./result_simba/pbg/mouse_neurons_downsample.500cells
# Before filtering:
# 500 cells, 27998 genes
# Filter genes based on min_n_cells
# After filtering out low-expressed genes:
# 500 cells, 12798 genes
# before filtering:
# 500 cells,  12798 genes
# filter cells based on min_n_genes
# after filtering out low-quality cells:
# 497 cells,  12798 genes
# 2000 variable genes are selected.
# relation0: source: C, destination: G
# #edges: 45833
# relation1: source: C, destination: G
# #edges: 46041
# relation2: source: C, destination: G
# #edges: 27578
# relation3: source: C, destination: G
# #edges: 13560
# relation4: source: C, destination: G
# #edges: 6208
# Total number of edges: 139220
# Writing graph file "pbg_graph.txt" to "./result_simba/pbg/mouse_neurons_downsample.500cells" ...
# **EDGE WRITE TIME: 1.865**
# Finished.
# Auto-estimated weight decay is 0.254526
# `.settings.pbg_params['wd']` has been updated to 0.254526
# Converting input data ...
# [2022-11-28 01:55:52.074799] Using the 5 relation types given in the config
# [2022-11-28 01:55:52.076165] Searching for the entities in the edge files...
# [2022-11-28 01:55:53.162916] Entity type C:
# [2022-11-28 01:55:53.164391] - Found 497 entities
# [2022-11-28 01:55:53.165323] - Removing the ones with fewer than 1 occurrences...
# [2022-11-28 01:55:53.166303] - Left with 497 entities
# [2022-11-28 01:55:53.167089] - Shuffling them...
# [2022-11-28 01:55:53.169622] Entity type G:
# [2022-11-28 01:55:53.170619] - Found 2000 entities
# [2022-11-28 01:55:53.171444] - Removing the ones with fewer than 1 occurrences...
# [2022-11-28 01:55:53.172786] - Left with 2000 entities
# [2022-11-28 01:55:53.173686] - Shuffling them...
# [2022-11-28 01:55:53.188060] Preparing counts and dictionaries for entities and relation types:
# [2022-11-28 01:55:53.189905] - Writing count of entity type C and partition 0
# [2022-11-28 01:55:53.193071] - Writing count of entity type G and partition 0
# [2022-11-28 01:55:53.200276] Preparing edge path ./result_simba/pbg/mouse_neurons_downsample.500cells/input/edge, out of the edges found in result_simba/pbg/mouse_neurons_downsample.500cells/pbg_graph.txt
# using fast version
# [2022-11-28 01:55:53.201622] Taking the fast train!
# [2022-11-28 01:55:55.575892] - Processed 100000 edges so far...
# [2022-11-28 01:55:57.697621] - Processed 139220 edges in total
# Starting training ...
# Finished
# Performing softmax transformation for query data 0;
# Successfully saved to: ./simba_benchmark_results/mouse_neurons_downsample.500cells_3/benchmark_results.pkl
# Total size (bytes): 2238
# 1000
# AnnData object with n_obs × n_vars = 1000 × 27998
#     obs: 'Cluster'
#     var: 'gene_ids'
#   0%|          | 0/4 [00:00<?, ?it/s]
# Before filtering:
# 1000 cells, 27998 genes
# Filter genes based on min_n_cells
# After filtering out low-expressed genes:
# 1000 cells, 13865 genes
# before filtering:
# 1000 cells,  13865 genes
# filter cells based on min_n_genes
# after filtering out low-quality cells:
# 991 cells,  13865 genes
# 2000 variable genes are selected.
# relation0: source: C, destination: G
# #edges: 78280
# relation1: source: C, destination: G
# #edges: 84055
# relation2: source: C, destination: G
# #edges: 49585
# relation3: source: C, destination: G
# #edges: 23150
# relation4: source: C, destination: G
# #edges: 10090
# Total number of edges: 245160
# Writing graph file "pbg_graph.txt" to "./result_simba/pbg/mouse_neurons_downsample.1000cells" ...
# **EDGE WRITE TIME: 3.114**
# Finished.
# Auto-estimated weight decay is 0.144539
# `.settings.pbg_params['wd']` has been updated to 0.144539
# Converting input data ...
# [2022-11-28 01:56:57.260846] Using the 5 relation types given in the config
# [2022-11-28 01:56:57.262372] Searching for the entities in the edge files...
# [2022-11-28 01:56:59.114873] Entity type C:
# [2022-11-28 01:56:59.116725] - Found 991 entities
# [2022-11-28 01:56:59.117672] - Removing the ones with fewer than 1 occurrences...
# [2022-11-28 01:56:59.118844] - Left with 991 entities
# [2022-11-28 01:56:59.119675] - Shuffling them...
# [2022-11-28 01:56:59.125451] Entity type G:
# [2022-11-28 01:56:59.126458] - Found 2000 entities
# [2022-11-28 01:56:59.127298] - Removing the ones with fewer than 1 occurrences...
# [2022-11-28 01:56:59.128642] - Left with 2000 entities
# [2022-11-28 01:56:59.129607] - Shuffling them...
# [2022-11-28 01:56:59.143286] Preparing counts and dictionaries for entities and relation types:
# [2022-11-28 01:56:59.144909] - Writing count of entity type C and partition 0
# [2022-11-28 01:56:59.149179] - Writing count of entity type G and partition 0
# [2022-11-28 01:56:59.156002] Preparing edge path ./result_simba/pbg/mouse_neurons_downsample.1000cells/input/edge, out of the edges found in result_simba/pbg/mouse_neurons_downsample.1000cells/pbg_graph.txt
# using fast version
# [2022-11-28 01:56:59.157431] Taking the fast train!
# [2022-11-28 01:57:01.554944] - Processed 100000 edges so far...
# [2022-11-28 01:57:03.891010] - Processed 200000 edges so far...
# [2022-11-28 01:57:05.948979] - Processed 245160 edges in total
# Starting training ...
# Finished
# Performing softmax transformation for query data 0;
# Successfully saved to: ./simba_benchmark_results/mouse_neurons_downsample.1000cells/benchmark_results.pkl
# Total size (bytes): 2238
#  - Removed graph dir: /home/mvinyard/SIMBA/tmp_run/./result_simba/pbg/mouse_neurons_downsample.1000cells
# Before filtering:
# 1000 cells, 27998 genes
# Filter genes based on min_n_cells
# After filtering out low-expressed genes:
# 1000 cells, 13865 genes
# before filtering:
# 1000 cells,  13865 genes
# filter cells based on min_n_genes
# after filtering out low-quality cells:
# 991 cells,  13865 genes
# 2000 variable genes are selected.
# relation0: source: C, destination: G
# #edges: 78280
# relation1: source: C, destination: G
# #edges: 84055
# relation2: source: C, destination: G
# #edges: 49585
# relation3: source: C, destination: G
# #edges: 23150
# relation4: source: C, destination: G
# #edges: 10090
# Total number of edges: 245160
# Writing graph file "pbg_graph.txt" to "./result_simba/pbg/mouse_neurons_downsample.1000cells" ...
# **EDGE WRITE TIME: 3.059**
# Finished.
# Auto-estimated weight decay is 0.144539
# `.settings.pbg_params['wd']` has been updated to 0.144539
# Converting input data ...
# [2022-11-28 01:57:57.054384] Using the 5 relation types given in the config
# [2022-11-28 01:57:57.055786] Searching for the entities in the edge files...
# [2022-11-28 01:57:58.870144] Entity type C:
# [2022-11-28 01:57:58.871588] - Found 991 entities
# [2022-11-28 01:57:58.872518] - Removing the ones with fewer than 1 occurrences...
# [2022-11-28 01:57:58.873845] - Left with 991 entities
# [2022-11-28 01:57:58.874835] - Shuffling them...
# [2022-11-28 01:57:58.880587] Entity type G:
# [2022-11-28 01:57:58.881525] - Found 2000 entities
# [2022-11-28 01:57:58.882373] - Removing the ones with fewer than 1 occurrences...
# [2022-11-28 01:57:58.883680] - Left with 2000 entities
# [2022-11-28 01:57:58.884750] - Shuffling them...
# [2022-11-28 01:57:58.897060] Preparing counts and dictionaries for entities and relation types:
# [2022-11-28 01:57:58.898800] - Writing count of entity type C and partition 0
# [2022-11-28 01:57:58.903002] - Writing count of entity type G and partition 0
# [2022-11-28 01:57:58.909395] Preparing edge path ./result_simba/pbg/mouse_neurons_downsample.1000cells/input/edge, out of the edges found in result_simba/pbg/mouse_neurons_downsample.1000cells/pbg_graph.txt
# using fast version
# [2022-11-28 01:57:58.910791] Taking the fast train!
# [2022-11-28 01:58:01.295398] - Processed 100000 edges so far...
# [2022-11-28 01:58:03.615712] - Processed 200000 edges so far...
# [2022-11-28 01:58:05.723483] - Processed 245160 edges in total
# Starting training ...
# Finished
# Performing softmax transformation for query data 0;
# Successfully saved to: ./simba_benchmark_results/mouse_neurons_downsample.1000cells_1/benchmark_results.pkl
# Total size (bytes): 2238
#  - Removed graph dir: /home/mvinyard/SIMBA/tmp_run/./result_simba/pbg/mouse_neurons_downsample.1000cells
# Before filtering:
# 1000 cells, 27998 genes
# Filter genes based on min_n_cells
# After filtering out low-expressed genes:
# 1000 cells, 13865 genes
# before filtering:
# 1000 cells,  13865 genes
# filter cells based on min_n_genes
# after filtering out low-quality cells:
# 991 cells,  13865 genes
# 2000 variable genes are selected.
# relation0: source: C, destination: G
# #edges: 78280
# relation1: source: C, destination: G
# #edges: 84055
# relation2: source: C, destination: G
# #edges: 49585
# relation3: source: C, destination: G
# #edges: 23150
# relation4: source: C, destination: G
# #edges: 10090
# Total number of edges: 245160
# Writing graph file "pbg_graph.txt" to "./result_simba/pbg/mouse_neurons_downsample.1000cells" ...
# **EDGE WRITE TIME: 3.011**
# Finished.
# Auto-estimated weight decay is 0.144539
# `.settings.pbg_params['wd']` has been updated to 0.144539
# Converting input data ...
# [2022-11-28 01:58:54.868850] Using the 5 relation types given in the config
# [2022-11-28 01:58:54.870201] Searching for the entities in the edge files...
# [2022-11-28 01:58:56.638905] Entity type C:
# [2022-11-28 01:58:56.640349] - Found 991 entities
# [2022-11-28 01:58:56.641376] - Removing the ones with fewer than 1 occurrences...
# [2022-11-28 01:58:56.642663] - Left with 991 entities
# [2022-11-28 01:58:56.643583] - Shuffling them...
# [2022-11-28 01:58:56.649431] Entity type G:
# [2022-11-28 01:58:56.650400] - Found 2000 entities
# [2022-11-28 01:58:56.651191] - Removing the ones with fewer than 1 occurrences...
# [2022-11-28 01:58:56.652569] - Left with 2000 entities
# [2022-11-28 01:58:56.653385] - Shuffling them...
# [2022-11-28 01:58:56.663983] Preparing counts and dictionaries for entities and relation types:
# [2022-11-28 01:58:56.667475] - Writing count of entity type C and partition 0
# [2022-11-28 01:58:56.672011] - Writing count of entity type G and partition 0
# [2022-11-28 01:58:56.678818] Preparing edge path ./result_simba/pbg/mouse_neurons_downsample.1000cells/input/edge, out of the edges found in result_simba/pbg/mouse_neurons_downsample.1000cells/pbg_graph.txt
# using fast version
# [2022-11-28 01:58:56.680239] Taking the fast train!
# [2022-11-28 01:58:59.081744] - Processed 100000 edges so far...
# [2022-11-28 01:59:01.433547] - Processed 200000 edges so far...
# [2022-11-28 01:59:03.568451] - Processed 245160 edges in total
# Starting training ...
# Finished
# Performing softmax transformation for query data 0;
# Successfully saved to: ./simba_benchmark_results/mouse_neurons_downsample.1000cells_2/benchmark_results.pkl
# Total size (bytes): 2238
#  - Removed graph dir: /home/mvinyard/SIMBA/tmp_run/./result_simba/pbg/mouse_neurons_downsample.1000cells
# Before filtering:
# 1000 cells, 27998 genes
# Filter genes based on min_n_cells
# After filtering out low-expressed genes:
# 1000 cells, 13865 genes
# before filtering:
# 1000 cells,  13865 genes
# filter cells based on min_n_genes
# after filtering out low-quality cells:
# 991 cells,  13865 genes
# 2000 variable genes are selected.
# relation0: source: C, destination: G
# #edges: 78280
# relation1: source: C, destination: G
# #edges: 84055
# relation2: source: C, destination: G
# #edges: 49585
# relation3: source: C, destination: G
# #edges: 23150
# relation4: source: C, destination: G
# #edges: 10090
# Total number of edges: 245160
# Writing graph file "pbg_graph.txt" to "./result_simba/pbg/mouse_neurons_downsample.1000cells" ...
# **EDGE WRITE TIME: 3.053**
# Finished.
# Auto-estimated weight decay is 0.144539
# `.settings.pbg_params['wd']` has been updated to 0.144539
# Converting input data ...
# [2022-11-28 01:59:52.935480] Using the 5 relation types given in the config
# [2022-11-28 01:59:52.936844] Searching for the entities in the edge files...
# [2022-11-28 01:59:54.714024] Entity type C:
# [2022-11-28 01:59:54.715377] - Found 991 entities
# [2022-11-28 01:59:54.716547] - Removing the ones with fewer than 1 occurrences...
# [2022-11-28 01:59:54.717757] - Left with 991 entities
# [2022-11-28 01:59:54.719526] - Shuffling them...
# [2022-11-28 01:59:54.725480] Entity type G:
# [2022-11-28 01:59:54.726437] - Found 2000 entities
# [2022-11-28 01:59:54.727396] - Removing the ones with fewer than 1 occurrences...
# [2022-11-28 01:59:54.728761] - Left with 2000 entities
# [2022-11-28 01:59:54.729656] - Shuffling them...
# [2022-11-28 01:59:54.740970] Preparing counts and dictionaries for entities and relation types:
# [2022-11-28 01:59:54.742795] - Writing count of entity type C and partition 0
# [2022-11-28 01:59:54.747136] - Writing count of entity type G and partition 0
# [2022-11-28 01:59:54.754077] Preparing edge path ./result_simba/pbg/mouse_neurons_downsample.1000cells/input/edge, out of the edges found in result_simba/pbg/mouse_neurons_downsample.1000cells/pbg_graph.txt
# using fast version
# [2022-11-28 01:59:54.755546] Taking the fast train!
# [2022-11-28 01:59:57.149803] - Processed 100000 edges so far...
# [2022-11-28 01:59:59.500553] - Processed 200000 edges so far...
# [2022-11-28 02:00:01.635847] - Processed 245160 edges in total
# Starting training ...
# Finished
# Performing softmax transformation for query data 0;
# Successfully saved to: ./simba_benchmark_results/mouse_neurons_downsample.1000cells_3/benchmark_results.pkl
# Total size (bytes): 2238
# 2500
# AnnData object with n_obs × n_vars = 2500 × 27998
#     obs: 'Cluster'
#     var: 'gene_ids'
#   0%|          | 0/4 [00:00<?, ?it/s]
# Before filtering:
# 2500 cells, 27998 genes
# Filter genes based on min_n_cells
# After filtering out low-expressed genes:
# 2500 cells, 15166 genes
# before filtering:
# 2500 cells,  15166 genes
# filter cells based on min_n_genes
# after filtering out low-quality cells:
# 2478 cells,  15166 genes
# 2000 variable genes are selected.
# relation0: source: C, destination: G
# #edges: 173881
# relation1: source: C, destination: G
# #edges: 182063
# relation2: source: C, destination: G
# #edges: 115334
# relation3: source: C, destination: G
# #edges: 47461
# relation4: source: C, destination: G
# #edges: 13670
# Total number of edges: 532409
# Writing graph file "pbg_graph.txt" to "./result_simba/pbg/mouse_neurons_downsample.2500cells" ...
# **EDGE WRITE TIME: 7.828**
# Finished.
# Auto-estimated weight decay is 0.066556
# `.settings.pbg_params['wd']` has been updated to 0.066556
# Converting input data ...
# [2022-11-28 02:01:02.904091] Using the 5 relation types given in the config
# [2022-11-28 02:01:02.905579] Searching for the entities in the edge files...
# [2022-11-28 02:01:06.616017] Entity type C:
# [2022-11-28 02:01:06.617471] - Found 2478 entities
# [2022-11-28 02:01:06.618473] - Removing the ones with fewer than 1 occurrences...
# [2022-11-28 02:01:06.619911] - Left with 2478 entities
# [2022-11-28 02:01:06.620932] - Shuffling them...
# [2022-11-28 02:01:06.632988] Entity type G:
# [2022-11-28 02:01:06.634105] - Found 2000 entities
# [2022-11-28 02:01:06.634971] - Removing the ones with fewer than 1 occurrences...
# [2022-11-28 02:01:06.636255] - Left with 2000 entities
# [2022-11-28 02:01:06.637243] - Shuffling them...
# [2022-11-28 02:01:06.650815] Preparing counts and dictionaries for entities and relation types:
# [2022-11-28 02:01:06.652740] - Writing count of entity type C and partition 0
# [2022-11-28 02:01:06.660382] - Writing count of entity type G and partition 0
# [2022-11-28 02:01:06.667041] Preparing edge path ./result_simba/pbg/mouse_neurons_downsample.2500cells/input/edge, out of the edges found in result_simba/pbg/mouse_neurons_downsample.2500cells/pbg_graph.txt
# using fast version
# [2022-11-28 02:01:06.668431] Taking the fast train!
# [2022-11-28 02:01:09.085378] - Processed 100000 edges so far...
# [2022-11-28 02:01:11.428484] - Processed 200000 edges so far...
# [2022-11-28 02:01:13.779946] - Processed 300000 edges so far...
# [2022-11-28 02:01:16.196694] - Processed 400000 edges so far...
# [2022-11-28 02:01:18.522123] - Processed 500000 edges so far...
# [2022-11-28 02:01:21.262385] - Processed 532409 edges in total
# Starting training ...
# Finished
# Performing softmax transformation for query data 0;
# Successfully saved to: ./simba_benchmark_results/mouse_neurons_downsample.2500cells/benchmark_results.pkl
# Total size (bytes): 2238
#  - Removed graph dir: /home/mvinyard/SIMBA/tmp_run/./result_simba/pbg/mouse_neurons_downsample.2500cells
# Before filtering:
# 2500 cells, 27998 genes
# Filter genes based on min_n_cells
# After filtering out low-expressed genes:
# 2500 cells, 15166 genes
# before filtering:
# 2500 cells,  15166 genes
# filter cells based on min_n_genes
# after filtering out low-quality cells:
# 2478 cells,  15166 genes
# 2000 variable genes are selected.
# relation0: source: C, destination: G
# #edges: 173881
# relation1: source: C, destination: G
# #edges: 182063
# relation2: source: C, destination: G
# #edges: 115334
# relation3: source: C, destination: G
# #edges: 47461
# relation4: source: C, destination: G
# #edges: 13670
# Total number of edges: 532409
# Writing graph file "pbg_graph.txt" to "./result_simba/pbg/mouse_neurons_downsample.2500cells" ...
# **EDGE WRITE TIME: 6.836**
# Finished.
# Auto-estimated weight decay is 0.066556
# `.settings.pbg_params['wd']` has been updated to 0.066556
# Converting input data ...
# [2022-11-28 02:03:37.593136] Using the 5 relation types given in the config
# [2022-11-28 02:03:37.594589] Searching for the entities in the edge files...
# [2022-11-28 02:03:40.973105] Entity type C:
# [2022-11-28 02:03:40.974558] - Found 2478 entities
# [2022-11-28 02:03:40.975558] - Removing the ones with fewer than 1 occurrences...
# [2022-11-28 02:03:40.977383] - Left with 2478 entities
# [2022-11-28 02:03:40.978468] - Shuffling them...
# [2022-11-28 02:03:40.991939] Entity type G:
# [2022-11-28 02:03:40.993019] - Found 2000 entities
# [2022-11-28 02:03:40.993914] - Removing the ones with fewer than 1 occurrences...
# [2022-11-28 02:03:40.995303] - Left with 2000 entities
# [2022-11-28 02:03:40.996183] - Shuffling them...
# [2022-11-28 02:03:41.010079] Preparing counts and dictionaries for entities and relation types:
# [2022-11-28 02:03:41.011827] - Writing count of entity type C and partition 0
# [2022-11-28 02:03:41.020567] - Writing count of entity type G and partition 0
# [2022-11-28 02:03:41.027764] Preparing edge path ./result_simba/pbg/mouse_neurons_downsample.2500cells/input/edge, out of the edges found in result_simba/pbg/mouse_neurons_downsample.2500cells/pbg_graph.txt
# using fast version
# [2022-11-28 02:03:41.028845] Taking the fast train!
# [2022-11-28 02:03:44.077030] - Processed 100000 edges so far...
# [2022-11-28 02:03:46.758689] - Processed 200000 edges so far...
# [2022-11-28 02:03:49.333577] - Processed 300000 edges so far...
# [2022-11-28 02:03:52.211078] - Processed 400000 edges so far...
# [2022-11-28 02:03:54.928799] - Processed 500000 edges so far...
# [2022-11-28 02:03:57.184513] - Processed 532409 edges in total
# Starting training ...
# Finished
# Performing softmax transformation for query data 0;
# Successfully saved to: ./simba_benchmark_results/mouse_neurons_downsample.2500cells_1/benchmark_results.pkl
# Total size (bytes): 2238
#  - Removed graph dir: /home/mvinyard/SIMBA/tmp_run/./result_simba/pbg/mouse_neurons_downsample.2500cells
# Before filtering:
# 2500 cells, 27998 genes
# Filter genes based on min_n_cells
# After filtering out low-expressed genes:
# 2500 cells, 15166 genes
# before filtering:
# 2500 cells,  15166 genes
# filter cells based on min_n_genes
# after filtering out low-quality cells:
# 2478 cells,  15166 genes
# 2000 variable genes are selected.
# relation0: source: C, destination: G
# #edges: 173881
# relation1: source: C, destination: G
# #edges: 182063
# relation2: source: C, destination: G
# #edges: 115334
# relation3: source: C, destination: G
# #edges: 47461
# relation4: source: C, destination: G
# #edges: 13670
# Total number of edges: 532409
# Writing graph file "pbg_graph.txt" to "./result_simba/pbg/mouse_neurons_downsample.2500cells" ...
# **EDGE WRITE TIME: 7.737**
# Finished.
# Auto-estimated weight decay is 0.066556
# `.settings.pbg_params['wd']` has been updated to 0.066556
# Converting input data ...
# [2022-11-28 02:04:59.826767] Using the 5 relation types given in the config
# [2022-11-28 02:04:59.828146] Searching for the entities in the edge files...
# [2022-11-28 02:05:04.584052] Entity type C:
# [2022-11-28 02:05:04.585484] - Found 2478 entities
# [2022-11-28 02:05:04.586398] - Removing the ones with fewer than 1 occurrences...
# [2022-11-28 02:05:04.587884] - Left with 2478 entities
# [2022-11-28 02:05:04.588773] - Shuffling them...
# [2022-11-28 02:05:04.606079] Entity type G:
# [2022-11-28 02:05:04.607041] - Found 2000 entities
# [2022-11-28 02:05:04.608342] - Removing the ones with fewer than 1 occurrences...
# [2022-11-28 02:05:04.609700] - Left with 2000 entities
# [2022-11-28 02:05:04.610598] - Shuffling them...
# [2022-11-28 02:05:04.625940] Preparing counts and dictionaries for entities and relation types:
# [2022-11-28 02:05:04.628423] - Writing count of entity type C and partition 0
# [2022-11-28 02:05:04.637368] - Writing count of entity type G and partition 0
# [2022-11-28 02:05:04.645167] Preparing edge path ./result_simba/pbg/mouse_neurons_downsample.2500cells/input/edge, out of the edges found in result_simba/pbg/mouse_neurons_downsample.2500cells/pbg_graph.txt
# using fast version
# [2022-11-28 02:05:04.646283] Taking the fast train!
# [2022-11-28 02:05:07.233926] - Processed 100000 edges so far...
# [2022-11-28 02:05:09.659955] - Processed 200000 edges so far...
# [2022-11-28 02:05:12.007659] - Processed 300000 edges so far...
# [2022-11-28 02:05:14.401512] - Processed 400000 edges so far...
# [2022-11-28 02:05:16.714680] - Processed 500000 edges so far...
# [2022-11-28 02:05:19.297138] - Processed 532409 edges in total
# Starting training ...
# Finished
# Performing softmax transformation for query data 0;
# Successfully saved to: ./simba_benchmark_results/mouse_neurons_downsample.2500cells_2/benchmark_results.pkl
# Total size (bytes): 2238
#  - Removed graph dir: /home/mvinyard/SIMBA/tmp_run/./result_simba/pbg/mouse_neurons_downsample.2500cells
# Before filtering:
# 2500 cells, 27998 genes
# Filter genes based on min_n_cells
# After filtering out low-expressed genes:
# 2500 cells, 15166 genes
# before filtering:
# 2500 cells,  15166 genes
# filter cells based on min_n_genes
# after filtering out low-quality cells:
# 2478 cells,  15166 genes
# 2000 variable genes are selected.
# relation0: source: C, destination: G
# #edges: 173881
# relation1: source: C, destination: G
# #edges: 182063
# relation2: source: C, destination: G
# #edges: 115334
# relation3: source: C, destination: G
# #edges: 47461
# relation4: source: C, destination: G
# #edges: 13670
# Total number of edges: 532409
# Writing graph file "pbg_graph.txt" to "./result_simba/pbg/mouse_neurons_downsample.2500cells" ...
# **EDGE WRITE TIME: 9.743**
# Finished.
# Auto-estimated weight decay is 0.066556
# `.settings.pbg_params['wd']` has been updated to 0.066556
# Converting input data ...
# [2022-11-28 02:06:20.786468] Using the 5 relation types given in the config
# [2022-11-28 02:06:20.787820] Searching for the entities in the edge files...
# [2022-11-28 02:06:25.555906] Entity type C:
# [2022-11-28 02:06:25.557346] - Found 2478 entities
# [2022-11-28 02:06:25.558487] - Removing the ones with fewer than 1 occurrences...
# [2022-11-28 02:06:25.559982] - Left with 2478 entities
# [2022-11-28 02:06:25.560925] - Shuffling them...
# [2022-11-28 02:06:25.578714] Entity type G:
# [2022-11-28 02:06:25.579709] - Found 2000 entities
# [2022-11-28 02:06:25.580594] - Removing the ones with fewer than 1 occurrences...
# [2022-11-28 02:06:25.581949] - Left with 2000 entities
# [2022-11-28 02:06:25.582814] - Shuffling them...
# [2022-11-28 02:06:25.599044] Preparing counts and dictionaries for entities and relation types:
# [2022-11-28 02:06:25.600753] - Writing count of entity type C and partition 0
# [2022-11-28 02:06:25.609590] - Writing count of entity type G and partition 0
# [2022-11-28 02:06:25.617206] Preparing edge path ./result_simba/pbg/mouse_neurons_downsample.2500cells/input/edge, out of the edges found in result_simba/pbg/mouse_neurons_downsample.2500cells/pbg_graph.txt
# using fast version
# [2022-11-28 02:06:25.618642] Taking the fast train!
# [2022-11-28 02:06:28.172363] - Processed 100000 edges so far...
# [2022-11-28 02:06:30.595506] - Processed 200000 edges so far...
# [2022-11-28 02:06:32.934715] - Processed 300000 edges so far...
# [2022-11-28 02:06:35.349800] - Processed 400000 edges so far...
# [2022-11-28 02:06:37.675096] - Processed 500000 edges so far...
# [2022-11-28 02:06:40.291890] - Processed 532409 edges in total
# Starting training ...
# Finished
# Performing softmax transformation for query data 0;
# Successfully saved to: ./simba_benchmark_results/mouse_neurons_downsample.2500cells_3/benchmark_results.pkl
# Total size (bytes): 2238
# 5000
# AnnData object with n_obs × n_vars = 5000 × 27998
#     obs: 'Cluster'
#     var: 'gene_ids'
#   0%|          | 0/4 [00:00<?, ?it/s]
# Before filtering:
# 5000 cells, 27998 genes
# Filter genes based on min_n_cells
# After filtering out low-expressed genes:
# 5000 cells, 16087 genes
# before filtering:
# 5000 cells,  16087 genes
# filter cells based on min_n_genes
# after filtering out low-quality cells:
# 4958 cells,  16087 genes
# 2000 variable genes are selected.
# relation0: source: C, destination: G
# #edges: 346633
# relation1: source: C, destination: G
# #edges: 340989
# relation2: source: C, destination: G
# #edges: 201474
# relation3: source: C, destination: G
# #edges: 75833
# relation4: source: C, destination: G
# #edges: 15823
# Total number of edges: 980752
# Writing graph file "pbg_graph.txt" to "./result_simba/pbg/mouse_neurons_downsample.5000cells" ...
# **EDGE WRITE TIME: 13.288**
# Finished.
# Auto-estimated weight decay is 0.036131
# `.settings.pbg_params['wd']` has been updated to 0.036131
# Converting input data ...
# [2022-11-28 02:07:50.687549] Using the 5 relation types given in the config
# [2022-11-28 02:07:50.688980] Searching for the entities in the edge files...
# [2022-11-28 02:07:59.525547] Entity type C:
# [2022-11-28 02:07:59.527026] - Found 4958 entities
# [2022-11-28 02:07:59.527900] - Removing the ones with fewer than 1 occurrences...
# [2022-11-28 02:07:59.529843] - Left with 4958 entities
# [2022-11-28 02:07:59.530898] - Shuffling them...
# [2022-11-28 02:07:59.570011] Entity type G:
# [2022-11-28 02:07:59.571360] - Found 2000 entities
# [2022-11-28 02:07:59.572555] - Removing the ones with fewer than 1 occurrences...
# [2022-11-28 02:07:59.574200] - Left with 2000 entities
# [2022-11-28 02:07:59.575081] - Shuffling them...
# [2022-11-28 02:07:59.591006] Preparing counts and dictionaries for entities and relation types:
# [2022-11-28 02:07:59.593204] - Writing count of entity type C and partition 0
# [2022-11-28 02:07:59.609521] - Writing count of entity type G and partition 0
# [2022-11-28 02:07:59.617690] Preparing edge path ./result_simba/pbg/mouse_neurons_downsample.5000cells/input/edge, out of the edges found in result_simba/pbg/mouse_neurons_downsample.5000cells/pbg_graph.txt
# using fast version
# [2022-11-28 02:07:59.619314] Taking the fast train!
# [2022-11-28 02:08:02.124357] - Processed 100000 edges so far...
# [2022-11-28 02:08:04.528996] - Processed 200000 edges so far...
# [2022-11-28 02:08:06.845862] - Processed 300000 edges so far...
# [2022-11-28 02:08:09.217376] - Processed 400000 edges so far...
# [2022-11-28 02:08:11.515847] - Processed 500000 edges so far...
# [2022-11-28 02:08:13.798256] - Processed 600000 edges so far...
# [2022-11-28 02:08:16.069993] - Processed 700000 edges so far...
# [2022-11-28 02:08:18.483553] - Processed 800000 edges so far...
# [2022-11-28 02:08:20.751539] - Processed 900000 edges so far...
# [2022-11-28 02:08:25.499835] - Processed 980752 edges in total
# Starting training ...
# Finished
# Performing softmax transformation for query data 0;
# Successfully saved to: ./simba_benchmark_results/mouse_neurons_downsample.5000cells/benchmark_results.pkl
# Total size (bytes): 2238
#  - Removed graph dir: /home/mvinyard/SIMBA/tmp_run/./result_simba/pbg/mouse_neurons_downsample.5000cells
# Before filtering:
# 5000 cells, 27998 genes
# Filter genes based on min_n_cells
# After filtering out low-expressed genes:
# 5000 cells, 16087 genes
# before filtering:
# 5000 cells,  16087 genes
# filter cells based on min_n_genes
# after filtering out low-quality cells:
# 4958 cells,  16087 genes
# 2000 variable genes are selected.
# relation0: source: C, destination: G
# #edges: 346633
# relation1: source: C, destination: G
# #edges: 340989
# relation2: source: C, destination: G
# #edges: 201474
# relation3: source: C, destination: G
# #edges: 75833
# relation4: source: C, destination: G
# #edges: 15823
# Total number of edges: 980752
# Writing graph file "pbg_graph.txt" to "./result_simba/pbg/mouse_neurons_downsample.5000cells" ...
# **EDGE WRITE TIME: 13.316**
# Finished.
# Auto-estimated weight decay is 0.036131
# `.settings.pbg_params['wd']` has been updated to 0.036131
# Converting input data ...
# [2022-11-28 02:09:39.400909] Using the 5 relation types given in the config
# [2022-11-28 02:09:39.402412] Searching for the entities in the edge files...
# [2022-11-28 02:09:48.210496] Entity type C:
# [2022-11-28 02:09:48.212362] - Found 4958 entities
# [2022-11-28 02:09:48.213165] - Removing the ones with fewer than 1 occurrences...
# [2022-11-28 02:09:48.215298] - Left with 4958 entities
# [2022-11-28 02:09:48.216233] - Shuffling them...
# [2022-11-28 02:09:48.250346] Entity type G:
# [2022-11-28 02:09:48.251427] - Found 2000 entities
# [2022-11-28 02:09:48.252225] - Removing the ones with fewer than 1 occurrences...
# [2022-11-28 02:09:48.253823] - Left with 2000 entities
# [2022-11-28 02:09:48.254825] - Shuffling them...
# [2022-11-28 02:09:48.269723] Preparing counts and dictionaries for entities and relation types:
# [2022-11-28 02:09:48.271736] - Writing count of entity type C and partition 0
# [2022-11-28 02:09:48.287513] - Writing count of entity type G and partition 0
# [2022-11-28 02:09:48.295063] Preparing edge path ./result_simba/pbg/mouse_neurons_downsample.5000cells/input/edge, out of the edges found in result_simba/pbg/mouse_neurons_downsample.5000cells/pbg_graph.txt
# using fast version
# [2022-11-28 02:09:48.296534] Taking the fast train!
# [2022-11-28 02:09:50.944503] - Processed 100000 edges so far...
# [2022-11-28 02:09:53.484682] - Processed 200000 edges so far...
# [2022-11-28 02:09:55.959026] - Processed 300000 edges so far...
# [2022-11-28 02:09:58.373358] - Processed 400000 edges so far...
# [2022-11-28 02:10:01.020030] - Processed 500000 edges so far...
# [2022-11-28 02:10:03.368224] - Processed 600000 edges so far...
# [2022-11-28 02:10:05.847268] - Processed 700000 edges so far...
# [2022-11-28 02:10:08.250567] - Processed 800000 edges so far...
# [2022-11-28 02:10:10.546231] - Processed 900000 edges so far...
# [2022-11-28 02:10:15.997325] - Processed 980752 edges in total
# Starting training ...
# Finished
# Performing softmax transformation for query data 0;
# Successfully saved to: ./simba_benchmark_results/mouse_neurons_downsample.5000cells_1/benchmark_results.pkl
# Total size (bytes): 2238
#  - Removed graph dir: /home/mvinyard/SIMBA/tmp_run/./result_simba/pbg/mouse_neurons_downsample.5000cells
# Before filtering:
# 5000 cells, 27998 genes
# Filter genes based on min_n_cells
# After filtering out low-expressed genes:
# 5000 cells, 16087 genes
# before filtering:
# 5000 cells,  16087 genes
# filter cells based on min_n_genes
# after filtering out low-quality cells:
# 4958 cells,  16087 genes
# 2000 variable genes are selected.
# relation0: source: C, destination: G
# #edges: 346633
# relation1: source: C, destination: G
# #edges: 340989
# relation2: source: C, destination: G
# #edges: 201474
# relation3: source: C, destination: G
# #edges: 75833
# relation4: source: C, destination: G
# #edges: 15823
# Total number of edges: 980752
# Writing graph file "pbg_graph.txt" to "./result_simba/pbg/mouse_neurons_downsample.5000cells" ...
# **EDGE WRITE TIME: 12.576**
# Finished.
# Auto-estimated weight decay is 0.036131
# `.settings.pbg_params['wd']` has been updated to 0.036131
# Converting input data ...
# [2022-11-28 02:11:30.487235] Using the 5 relation types given in the config
# [2022-11-28 02:11:30.488734] Searching for the entities in the edge files...
# [2022-11-28 02:11:39.098280] Entity type C:
# [2022-11-28 02:11:39.099698] - Found 4958 entities
# [2022-11-28 02:11:39.100770] - Removing the ones with fewer than 1 occurrences...
# [2022-11-28 02:11:39.102577] - Left with 4958 entities
# [2022-11-28 02:11:39.103432] - Shuffling them...
# [2022-11-28 02:11:39.133712] Entity type G:
# [2022-11-28 02:11:39.134859] - Found 2000 entities
# [2022-11-28 02:11:39.135690] - Removing the ones with fewer than 1 occurrences...
# [2022-11-28 02:11:39.137004] - Left with 2000 entities
# [2022-11-28 02:11:39.138040] - Shuffling them...
# [2022-11-28 02:11:39.151457] Preparing counts and dictionaries for entities and relation types:
# [2022-11-28 02:11:39.153415] - Writing count of entity type C and partition 0
# [2022-11-28 02:11:39.168844] - Writing count of entity type G and partition 0
# [2022-11-28 02:11:39.175870] Preparing edge path ./result_simba/pbg/mouse_neurons_downsample.5000cells/input/edge, out of the edges found in result_simba/pbg/mouse_neurons_downsample.5000cells/pbg_graph.txt
# using fast version
# [2022-11-28 02:11:39.177269] Taking the fast train!
# [2022-11-28 02:11:41.652211] - Processed 100000 edges so far...
# [2022-11-28 02:11:44.031720] - Processed 200000 edges so far...
# [2022-11-28 02:11:46.345252] - Processed 300000 edges so far...
# [2022-11-28 02:11:48.751849] - Processed 400000 edges so far...
# [2022-11-28 02:11:51.066153] - Processed 500000 edges so far...
# [2022-11-28 02:11:53.362951] - Processed 600000 edges so far...
# [2022-11-28 02:11:55.653030] - Processed 700000 edges so far...
# [2022-11-28 02:11:58.081228] - Processed 800000 edges so far...
# [2022-11-28 02:12:00.366414] - Processed 900000 edges so far...
# [2022-11-28 02:12:05.482170] - Processed 980752 edges in total
# Starting training ...
# Finished
# Performing softmax transformation for query data 0;
# Successfully saved to: ./simba_benchmark_results/mouse_neurons_downsample.5000cells_2/benchmark_results.pkl
# Total size (bytes): 2238
#  - Removed graph dir: /home/mvinyard/SIMBA/tmp_run/./result_simba/pbg/mouse_neurons_downsample.5000cells
# Before filtering:
# 5000 cells, 27998 genes
# Filter genes based on min_n_cells
# After filtering out low-expressed genes:
# 5000 cells, 16087 genes
# before filtering:
# 5000 cells,  16087 genes
# filter cells based on min_n_genes
# after filtering out low-quality cells:
# 4958 cells,  16087 genes
# 2000 variable genes are selected.
# relation0: source: C, destination: G
# #edges: 346633
# relation1: source: C, destination: G
# #edges: 340989
# relation2: source: C, destination: G
# #edges: 201474
# relation3: source: C, destination: G
# #edges: 75833
# relation4: source: C, destination: G
# #edges: 15823
# Total number of edges: 980752
# Writing graph file "pbg_graph.txt" to "./result_simba/pbg/mouse_neurons_downsample.5000cells" ...
# **EDGE WRITE TIME: 12.389**
# Finished.
# Auto-estimated weight decay is 0.036131
# `.settings.pbg_params['wd']` has been updated to 0.036131
# Converting input data ...
# [2022-11-28 02:13:18.451760] Using the 5 relation types given in the config
# [2022-11-28 02:13:18.453220] Searching for the entities in the edge files...
# [2022-11-28 02:13:27.327929] Entity type C:
# [2022-11-28 02:13:27.329779] - Found 4958 entities
# [2022-11-28 02:13:27.331339] - Removing the ones with fewer than 1 occurrences...
# [2022-11-28 02:13:27.333926] - Left with 4958 entities
# [2022-11-28 02:13:27.335226] - Shuffling them...
# [2022-11-28 02:13:27.372543] Entity type G:
# [2022-11-28 02:13:27.374253] - Found 2000 entities
# [2022-11-28 02:13:27.375593] - Removing the ones with fewer than 1 occurrences...
# [2022-11-28 02:13:27.377571] - Left with 2000 entities
# [2022-11-28 02:13:27.378900] - Shuffling them...
# [2022-11-28 02:13:27.396305] Preparing counts and dictionaries for entities and relation types:
# [2022-11-28 02:13:27.399335] - Writing count of entity type C and partition 0
# [2022-11-28 02:13:27.420669] - Writing count of entity type G and partition 0
# [2022-11-28 02:13:27.430211] Preparing edge path ./result_simba/pbg/mouse_neurons_downsample.5000cells/input/edge, out of the edges found in result_simba/pbg/mouse_neurons_downsample.5000cells/pbg_graph.txt
# using fast version
# [2022-11-28 02:13:27.432746] Taking the fast train!
# [2022-11-28 02:13:31.183991] - Processed 100000 edges so far...
# [2022-11-28 02:13:33.569616] - Processed 200000 edges so far...
# [2022-11-28 02:13:35.920627] - Processed 300000 edges so far...
# [2022-11-28 02:13:38.329269] - Processed 400000 edges so far...
# [2022-11-28 02:13:40.664906] - Processed 500000 edges so far...
# [2022-11-28 02:13:42.984501] - Processed 600000 edges so far...
# [2022-11-28 02:13:45.273671] - Processed 700000 edges so far...
# [2022-11-28 02:13:47.657461] - Processed 800000 edges so far...
# [2022-11-28 02:13:49.961043] - Processed 900000 edges so far...
# [2022-11-28 02:13:54.795829] - Processed 980752 edges in total
# Starting training ...
# Finished
# Performing softmax transformation for query data 0;
# Successfully saved to: ./simba_benchmark_results/mouse_neurons_downsample.5000cells_3/benchmark_results.pkl
# Total size (bytes): 2238
# 10000
# AnnData object with n_obs × n_vars = 10000 × 27998
#     obs: 'Cluster'
#     var: 'gene_ids'
#   0%|          | 0/4 [00:00<?, ?it/s]
# Before filtering:
# 10000 cells, 27998 genes
# Filter genes based on min_n_cells
# After filtering out low-expressed genes:
# 10000 cells, 16966 genes
# before filtering:
# 10000 cells,  16966 genes
# filter cells based on min_n_genes
# after filtering out low-quality cells:
# 9899 cells,  16966 genes
# 2000 variable genes are selected.
# relation0: source: C, destination: G
# #edges: 722270
# relation1: source: C, destination: G
# #edges: 657599
# relation2: source: C, destination: G
# #edges: 372480
# relation3: source: C, destination: G
# #edges: 134133
# relation4: source: C, destination: G
# #edges: 24787
# Total number of edges: 1911269
# Writing graph file "pbg_graph.txt" to "./result_simba/pbg/mouse_neurons_downsample.10000cells" ...
# **EDGE WRITE TIME: 25.070**
# Finished.
# Auto-estimated weight decay is 0.01854
# `.settings.pbg_params['wd']` has been updated to 0.01854
# Converting input data ...
# [2022-11-28 02:15:24.188245] Using the 5 relation types given in the config
# [2022-11-28 02:15:24.189693] Searching for the entities in the edge files...
# [2022-11-28 02:15:39.336505] Entity type C:
# [2022-11-28 02:15:39.337990] - Found 9899 entities
# [2022-11-28 02:15:39.339264] - Removing the ones with fewer than 1 occurrences...
# [2022-11-28 02:15:39.342259] - Left with 9899 entities
# [2022-11-28 02:15:39.344193] - Shuffling them...
# [2022-11-28 02:15:39.396744] Entity type G:
# [2022-11-28 02:15:39.398423] - Found 2000 entities
# [2022-11-28 02:15:39.399213] - Removing the ones with fewer than 1 occurrences...
# [2022-11-28 02:15:39.400744] - Left with 2000 entities
# [2022-11-28 02:15:39.401552] - Shuffling them...
# [2022-11-28 02:15:39.415054] Preparing counts and dictionaries for entities and relation types:
# [2022-11-28 02:15:39.417401] - Writing count of entity type C and partition 0
# [2022-11-28 02:15:39.443111] - Writing count of entity type G and partition 0
# [2022-11-28 02:15:39.450148] Preparing edge path ./result_simba/pbg/mouse_neurons_downsample.10000cells/input/edge, out of the edges found in result_simba/pbg/mouse_neurons_downsample.10000cells/pbg_graph.txt
# using fast version
# [2022-11-28 02:15:39.451813] Taking the fast train!
# [2022-11-28 02:15:41.889583] - Processed 100000 edges so far...
# [2022-11-28 02:15:44.268439] - Processed 200000 edges so far...
# [2022-11-28 02:15:46.599443] - Processed 300000 edges so far...
# [2022-11-28 02:15:48.974720] - Processed 400000 edges so far...
# [2022-11-28 02:15:51.284130] - Processed 500000 edges so far...
# [2022-11-28 02:15:53.559499] - Processed 600000 edges so far...
# [2022-11-28 02:15:55.856625] - Processed 700000 edges so far...
# [2022-11-28 02:15:58.230413] - Processed 800000 edges so far...
# [2022-11-28 02:16:00.520276] - Processed 900000 edges so far...
# [2022-11-28 02:16:02.826280] - Processed 1000000 edges so far...
# [2022-11-28 02:16:05.177297] - Processed 1100000 edges so far...
# [2022-11-28 02:16:07.564179] - Processed 1200000 edges so far...
# [2022-11-28 02:16:09.958669] - Processed 1300000 edges so far...
# [2022-11-28 02:16:12.334340] - Processed 1400000 edges so far...
# [2022-11-28 02:16:14.886400] - Processed 1500000 edges so far...
# [2022-11-28 02:16:17.204610] - Processed 1600000 edges so far...
# [2022-11-28 02:16:19.499363] - Processed 1700000 edges so far...
# [2022-11-28 02:16:21.835371] - Processed 1800000 edges so far...
# [2022-11-28 02:16:24.149205] - Processed 1900000 edges so far...
# [2022-11-28 02:16:29.401355] - Processed 1911269 edges in total
# Starting training ...
# Finished
# Performing softmax transformation for query data 0;
# ...
# [2022-11-28 20:10:38.172702] - Processed 72800000 edges so far...
# [2022-11-28 20:10:40.360990] - Processed 72900000 edges so far...
# [2022-11-28 20:10:42.483637] - Processed 73000000 edges so far...
# [2022-11-28 20:10:44.614161] - Processed 73100000 edges so far...
# [2022-11-28 20:10:46.760788] - Processed 73200000 edges so far...
# [2022-11-28 20:10:48.905973] - Processed 73300000 edges so far...
# [2022-11-28 20:10:51.650400] - Processed 73400000 edges so far...
# [2022-11-28 20:10:53.768847] - Processed 73500000 edges so far...
# [2022-11-28 20:10:55.960352] - Processed 73600000 edges so far...
# [2022-11-28 20:10:58.112474] - Processed 73700000 edges so far...
# [2022-11-28 20:11:00.253305] - Processed 73800000 edges so far...
# [2022-11-28 20:11:02.393970] - Processed 73900000 edges so far...
# [2022-11-28 20:11:04.535198] - Processed 74000000 edges so far...
# [2022-11-28 20:11:06.678717] - Processed 74100000 edges so far...
# [2022-11-28 20:11:08.841852] - Processed 74200000 edges so far...
# [2022-11-28 20:11:11.005350] - Processed 74300000 edges so far...
# [2022-11-28 20:11:15.834446] - Processed 74400000 edges so far...
# [2022-11-28 20:11:20.174338] - Processed 74500000 edges so far...
# [2022-11-28 20:11:22.367723] - Processed 74600000 edges so far...
# [2022-11-28 20:11:24.536032] - Processed 74700000 edges so far...
# [2022-11-28 20:11:26.692036] - Processed 74800000 edges so far...
# [2022-11-28 20:11:28.849954] - Processed 74900000 edges so far...
# [2022-11-28 20:11:30.996792] - Processed 75000000 edges so far...
# [2022-11-28 20:11:33.134429] - Processed 75100000 edges so far...
# [2022-11-28 20:11:35.285392] - Processed 75200000 edges so far...
# [2022-11-28 20:11:37.415711] - Processed 75300000 edges so far...
# [2022-11-28 20:11:39.557776] - Processed 75400000 edges so far...
# [2022-11-28 20:11:41.705557] - Processed 75500000 edges so far...
# [2022-11-28 20:11:43.857505] - Processed 75600000 edges so far...
# [2022-11-28 20:11:45.996091] - Processed 75700000 edges so far...
# [2022-11-28 20:11:48.145076] - Processed 75800000 edges so far...
# [2022-11-28 20:11:50.267597] - Processed 75900000 edges so far...
# [2022-11-28 20:11:52.360810] - Processed 76000000 edges so far...
# [2022-11-28 20:11:54.422841] - Processed 76100000 edges so far...
# [2022-11-28 20:11:56.471053] - Processed 76200000 edges so far...
# [2022-11-28 20:11:58.549049] - Processed 76300000 edges so far...
# [2022-11-28 20:12:00.632219] - Processed 76400000 edges so far...
# [2022-11-28 20:12:02.690686] - Processed 76500000 edges so far...
# [2022-11-28 20:12:04.787792] - Processed 76600000 edges so far...
# [2022-11-28 20:12:06.867345] - Processed 76700000 edges so far...
# [2022-11-28 20:12:09.014279] - Processed 76800000 edges so far...
# [2022-11-28 20:12:11.210328] - Processed 76900000 edges so far...
# [2022-11-28 20:12:13.306508] - Processed 77000000 edges so far...
# [2022-11-28 20:12:15.384496] - Processed 77100000 edges so far...
# [2022-11-28 20:12:17.466523] - Processed 77200000 edges so far...
# [2022-11-28 20:12:19.583773] - Processed 77300000 edges so far...
# [2022-11-28 20:12:21.659495] - Processed 77400000 edges so far...
# [2022-11-28 20:12:23.767789] - Processed 77500000 edges so far...
# [2022-11-28 20:12:25.889216] - Processed 77600000 edges so far...
# [2022-11-28 20:12:27.997968] - Processed 77700000 edges so far...
# [2022-11-28 20:12:30.127128] - Processed 77800000 edges so far...
# [2022-11-28 20:12:32.267686] - Processed 77900000 edges so far...
# [2022-11-28 20:12:34.386927] - Processed 78000000 edges so far...
# [2022-11-28 20:12:36.502853] - Processed 78100000 edges so far...
# [2022-11-28 20:12:38.666507] - Processed 78200000 edges so far...
# [2022-11-28 20:12:40.827810] - Processed 78300000 edges so far...
# [2022-11-28 20:12:43.026554] - Processed 78400000 edges so far...
# [2022-11-28 20:12:45.222420] - Processed 78500000 edges so far...
# [2022-11-28 20:12:47.388060] - Processed 78600000 edges so far...
# [2022-11-28 20:12:49.561060] - Processed 78700000 edges so far...
# [2022-11-28 20:12:51.675388] - Processed 78800000 edges so far...
# [2022-11-28 20:12:53.808741] - Processed 78900000 edges so far...
# [2022-11-28 20:12:55.979923] - Processed 79000000 edges so far...
# [2022-11-28 20:12:58.109828] - Processed 79100000 edges so far...
# [2022-11-28 20:13:00.274790] - Processed 79200000 edges so far...
# [2022-11-28 20:13:02.418262] - Processed 79300000 edges so far...
# [2022-11-28 20:13:04.560537] - Processed 79400000 edges so far...
# [2022-11-28 20:13:06.678536] - Processed 79500000 edges so far...
# [2022-11-28 20:13:08.833600] - Processed 79600000 edges so far...
# [2022-11-28 20:13:11.017040] - Processed 79700000 edges so far...
# [2022-11-28 20:13:13.207587] - Processed 79800000 edges so far...
# [2022-11-28 20:13:15.409870] - Processed 79900000 edges so far...
# [2022-11-28 20:13:17.643546] - Processed 80000000 edges so far...
# [2022-11-28 20:13:19.862985] - Processed 80100000 edges so far...
# [2022-11-28 20:13:22.099229] - Processed 80200000 edges so far...
# [2022-11-28 20:13:24.322350] - Processed 80300000 edges so far...
# [2022-11-28 20:13:26.477644] - Processed 80400000 edges so far...
# [2022-11-28 20:13:28.701500] - Processed 80500000 edges so far...
# [2022-11-28 20:13:30.901842] - Processed 80600000 edges so far...
# [2022-11-28 20:13:33.061053] - Processed 80700000 edges so far...
# [2022-11-28 20:13:35.257522] - Processed 80800000 edges so far...
# [2022-11-28 20:13:37.408552] - Processed 80900000 edges so far...
# [2022-11-28 20:13:39.604540] - Processed 81000000 edges so far...
# [2022-11-28 20:13:41.800653] - Processed 81100000 edges so far...
# [2022-11-28 20:13:43.973352] - Processed 81200000 edges so far...
# [2022-11-28 20:13:46.142225] - Processed 81300000 edges so far...
# [2022-11-28 20:13:48.344149] - Processed 81400000 edges so far...
# [2022-11-28 20:13:50.553000] - Processed 81500000 edges so far...
# [2022-11-28 20:13:52.673874] - Processed 81600000 edges so far...
# [2022-11-28 20:13:54.771334] - Processed 81700000 edges so far...
# [2022-11-28 20:13:56.852463] - Processed 81800000 edges so far...
# [2022-11-28 20:13:58.926873] - Processed 81900000 edges so far...
# [2022-11-28 20:14:01.042253] - Processed 82000000 edges so far...
# [2022-11-28 20:14:03.145381] - Processed 82100000 edges so far...
# [2022-11-28 20:14:05.274750] - Processed 82200000 edges so far...
# [2022-11-28 20:14:07.390773] - Processed 82300000 edges so far...
# [2022-11-28 20:14:09.521485] - Processed 82400000 edges so far...
# [2022-11-28 20:14:11.848996] - Processed 82500000 edges so far...
# [2022-11-28 20:14:13.974017] - Processed 82600000 edges so far...
# [2022-11-28 20:14:16.114300] - Processed 82700000 edges so far...
# [2022-11-28 20:14:18.277052] - Processed 82800000 edges so far...
# [2022-11-28 20:14:20.607501] - Processed 82900000 edges so far...
# [2022-11-28 20:14:24.294284] - Processed 83000000 edges so far...
# [2022-11-28 20:14:26.427132] - Processed 83100000 edges so far...
# [2022-11-28 20:14:28.536950] - Processed 83200000 edges so far...
# [2022-11-28 20:14:30.689642] - Processed 83300000 edges so far...
# [2022-11-28 20:14:32.825550] - Processed 83400000 edges so far...
# [2022-11-28 20:14:34.992941] - Processed 83500000 edges so far...
# [2022-11-28 20:14:37.139739] - Processed 83600000 edges so far...
# [2022-11-28 20:14:39.293638] - Processed 83700000 edges so far...
# [2022-11-28 20:14:41.489242] - Processed 83800000 edges so far...
# [2022-11-28 20:14:43.658136] - Processed 83900000 edges so far...
# [2022-11-28 20:14:45.832904] - Processed 84000000 edges so far...
# [2022-11-28 20:14:48.016399] - Processed 84100000 edges so far...
# [2022-11-28 20:14:50.174950] - Processed 84200000 edges so far...
# [2022-11-28 20:14:52.385911] - Processed 84300000 edges so far...
# [2022-11-28 20:14:54.590223] - Processed 84400000 edges so far...
# [2022-11-28 20:14:56.728347] - Processed 84500000 edges so far...
# [2022-11-28 20:14:58.869485] - Processed 84600000 edges so far...
# [2022-11-28 20:15:01.026253] - Processed 84700000 edges so far...
# [2022-11-28 20:15:03.188792] - Processed 84800000 edges so far...
# [2022-11-28 20:15:05.385836] - Processed 84900000 edges so far...
# [2022-11-28 20:18:13.555185] - Processed 84998357 edges in total
# Starting training ...
# Finished
# Performing softmax transformation for query data 0;
# Successfully saved to: ./simba_benchmark_results/mouse_neurons_downsample.500000cells_3/benchmark_results.pkl
# Total size (bytes): 2238
# 1000000
# AnnData object with n_obs × n_vars = 1000000 × 27998
#     obs: 'Cluster'
#     var: 'gene_ids'
#   0%|          | 0/4 [00:00<?, ?it/s]
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Input In [4], in <cell line: 1>()
#       7     adata_downsample = adata
#       8     n_cells = 1306127
# ---> 10 simba_outs = pb.methods.simba(
#      11     adata_downsample, n_iters=4, dataset="mouse_neurons_downsample.{}cells".format(n_cells)
#      12 )
#
# File ~/SIMBA/simba_performance_benchmark/performance_benchmark/methods/_simba/_run_simba.py:152, in run_simba(adata, n_iters, method_dir, dataset, parent_path, graph_dir, n_cells, debug)
#     150 filename = tl.mk_save_path(method_dir, dataset, ext=".pkl")
#     151 tl.clean_graph_dir(dataset=dataset, parent_path=parent_path, graph_dir=graph_dir)
# --> 152 run_i = _run_simba_traced(adata, dataset)
#     154 outs[i] = format_simba_results(
#     155     run=run_i,
#     156     save_filename=filename,
#    (...)
#     161     return_saved_outs=True,
#     162 )
#     163 if debug:
#
# File ~/SIMBA/simba_performance_benchmark/performance_benchmark/_tools/_time_tracer.py:8, in time_tracer.<locals>.timing_wrapper(*args, **kwargs)
#       5 def timing_wrapper(*args, **kwargs):
#       7     t0 = time.time()
# ----> 8     result = abstract_func(*args, **kwargs)
#       9     tf = time.time()
#      11     t_delta = tf - t0
#
# File ~/SIMBA/simba_performance_benchmark/performance_benchmark/_tools/_memory_tracer.py:64, in memory_tracer.<locals>.wrapper(*args, **kwargs)
#      61 def wrapper(*args, **kwargs):
#      63     tracemalloc.start()
# ---> 64     result = func(*args, **kwargs)
#      65     mu = MemoryUsage()
#      67     if not result is None:
#
# File ~/SIMBA/simba_performance_benchmark/performance_benchmark/methods/_simba/_run_simba.py:124, in _run_simba_traced(adata, dataset)
#     119 @time_tracer
#     120 @memory_tracer
#     121 def _run_simba_traced(adata, dataset):
#     123     run_simba = RunSIMBA(adata)
# --> 124     run_simba.preprocess()
#     125     run_simba.gen_graph(dataset=dataset)
#     126     run_simba.modify_params()
#
# File ~/SIMBA/simba_performance_benchmark/performance_benchmark/methods/_simba/_run_simba.py:73, in RunSIMBA.preprocess(self)
#      71 def preprocess(self):
#      72     self._simba_pp = funcs.SimbaPreprocess()
# ---> 73     self._simba_pp(adata=self._adata)
#      74     self.adata_CG = self._simba_pp.outs[0]
#
# File ~/SIMBA/simba_performance_benchmark/performance_benchmark/_core/_traced_subroutine.py:35, in TracedSubRoutine.__call__(self, **kwargs)
#      33 """Call the forward method, which is wrapped by the tracer"""
#      34 self.__parse__(locals())
# ---> 35 result = self.__tracer__(**self._kwargs)
#      36 self.outs = result[0][0]
#      37 self.m, self.t = result[0][1], result[1]
#
# File ~/SIMBA/simba_performance_benchmark/performance_benchmark/_tools/_time_tracer.py:8, in time_tracer.<locals>.timing_wrapper(*args, **kwargs)
#       5 def timing_wrapper(*args, **kwargs):
#       7     t0 = time.time()
# ----> 8     result = abstract_func(*args, **kwargs)
#       9     tf = time.time()
#      11     t_delta = tf - t0
#
# File ~/SIMBA/simba_performance_benchmark/performance_benchmark/_tools/_memory_tracer.py:64, in memory_tracer.<locals>.wrapper(*args, **kwargs)
#      61 def wrapper(*args, **kwargs):
#      63     tracemalloc.start()
# ---> 64     result = func(*args, **kwargs)
#      65     mu = MemoryUsage()
#      67     if not result is None:
#
# File ~/SIMBA/simba_performance_benchmark/performance_benchmark/_core/_traced_subroutine.py:30, in TracedSubRoutine.__tracer__(self, kwargs)
#      26 @time_tracer
#      27 @memory_tracer
#      28 def __tracer__(self, kwargs):
#      29     """Trace forward"""
# ---> 30     return self.forward(**kwargs)
#
# File ~/SIMBA/simba_performance_benchmark/performance_benchmark/methods/_simba/_simba_funcs/_simba_preprocess.py:52, in SimbaPreprocess.forward(self, adata, min_n_cells, min_n_genes, quiet, method, n_top_genes, n_bins)
#      49     kw["adata"] = adata_CG
#      50     return run(**kw)
# ---> 52 t, m = f(getattr(getattr(si, mod), func), adata_CG, kwargs)
#      53 ResourceDict["m"][mod_func] = m.components
#      54 ResourceDict["t"][mod_func] = t
#
# File ~/SIMBA/simba_performance_benchmark/performance_benchmark/_tools/_memory_tracer.py:64, in memory_tracer.<locals>.wrapper(*args, **kwargs)
#      61 def wrapper(*args, **kwargs):
#      63     tracemalloc.start()
# ---> 64     result = func(*args, **kwargs)
#      65     mu = MemoryUsage()
#      67     if not result is None:
#
# File ~/SIMBA/simba_performance_benchmark/performance_benchmark/_tools/_time_tracer.py:8, in time_tracer.<locals>.timing_wrapper(*args, **kwargs)
#       5 def timing_wrapper(*args, **kwargs):
#       7     t0 = time.time()
# ----> 8     result = abstract_func(*args, **kwargs)
#       9     tf = time.time()
#      11     t_delta = tf - t0
#
# File ~/SIMBA/simba_performance_benchmark/performance_benchmark/methods/_simba/_simba_funcs/_simba_preprocess.py:50, in SimbaPreprocess.forward.<locals>.f(run, adata_CG, kwargs)
#      48 kw = tl.extract_func_kwargs(run, kwargs)
#      49 kw["adata"] = adata_CG
# ---> 50 return run(**kw)
#
# File ~/SIMBA/simba/simba/preprocessing/_qc.py:508, in filter_genes(adata, min_n_cells, max_n_cells, min_pct_cells, max_pct_cells, min_n_counts, max_n_counts, expr_cutoff)
#     506     n_cells = adata.var['n_cells']
#     507 else:
# --> 508     n_cells = np.sum(adata.X >= expr_cutoff, axis=0).A1
#     509     adata.var['n_cells'] = n_cells
#     510 if('pct_cells' in adata.var_keys()):
#
# File ~/.anaconda3/envs/simba_dev/lib/python3.9/site-packages/scipy/sparse/_compressed.py:338, in _cs_matrix.__ge__(self, other)
#     337 def __ge__(self, other):
# --> 338     return self._inequality(other, operator.ge, '_ge_',
#     339                             "Comparing a sparse matrix with a scalar "
#     340                             "less than zero using >= is inefficient, "
#     341                             "try using < instead.")
#
# File ~/.anaconda3/envs/simba_dev/lib/python3.9/site-packages/scipy/sparse/_compressed.py:297, in _cs_matrix._inequality(self, other, op, op_name, bad_scalar_msg)
#     295         return self._binopt(other_arr, op_name)
#     296     else:
# --> 297         return self._scalar_binopt(other, op)
#     298 # Dense other.
#     299 elif isdense(other):
#
# File ~/.anaconda3/envs/simba_dev/lib/python3.9/site-packages/scipy/sparse/_compressed.py:210, in _cs_matrix._scalar_binopt(self, other, op)
#     206 def _scalar_binopt(self, other, op):
#     207     """Scalar version of self._binopt, for cases in which no new nonzeros
#     208     are added. Produces a new spmatrix in canonical form.
#     209     """
# --> 210     self.sum_duplicates()
#     211     res = self._with_data(op(self.data, other), copy=True)
#     212     res.eliminate_zeros()
#
# File ~/.anaconda3/envs/simba_dev/lib/python3.9/site-packages/scipy/sparse/_compressed.py:1118, in _cs_matrix.sum_duplicates(self)
#    1116 if self.has_canonical_format:
#    1117     return
# -> 1118 self.sort_indices()
#    1120 M, N = self._swap(self.shape)
#    1121 _sparsetools.csr_sum_duplicates(M, N, self.indptr, self.indices,
#    1122                                 self.data)
#
# File ~/.anaconda3/envs/simba_dev/lib/python3.9/site-packages/scipy/sparse/_compressed.py:1164, in _cs_matrix.sort_indices(self)
#    1160 """Sort the indices of this matrix *in place*
#    1161 """
#    1163 if not self.has_sorted_indices:
# -> 1164     _sparsetools.csr_sort_indices(len(self.indptr) - 1, self.indptr,
#    1165                                   self.indices, self.data)
#    1166     self.has_sorted_indices = True
#
# KeyboardInterrupt:
