# %%
import performance_benchmark as pb
# Out:
# GPUTrainingCoordinator: GPU INSTALLED
# Available memory: 9 Gb
# Available vCPUs: 2

# %%
plot = pb.results.PlotTimeMemory(
    results_path="./results/",
    save=True,
    savename="./figs/compare_all_methods.time_memory.pancreas_rna_Baron_2016.svg",
    figsize=0.25,
    legend_loc=(3.5, 0.25),
    wspace=0.5,
)
