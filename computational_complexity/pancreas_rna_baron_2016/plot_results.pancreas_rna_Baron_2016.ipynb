# %%
import performance_benchmark as pb
# Out:
# Available memory: 32 Gb
# Available vCPUs: 10

# %%
plot = pb.results.PlotTimeMemory(results_path="./results/")
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In [2], line 1
# ----> 1 plot = pb.results.PlotTimeMemory(results_path="./results/")
#
# File ~/github/SIMBA/simba_performance_benchmark/performance_benchmark/results/_aggregate_plot_results.py:251, in PlotTimeMemory.__init__(self, results_path, memory_trace_path, wspace, **kwargs)
#     248 SIMBA_mem_augment = SIMBAMemoryAugmentation(self._compare)
#     250 self.plot_m = process_results_for_plot(self._compare, tm_key="m")
# --> 251 self.plot_m = SIMBA_mem_augment.update(self.plot_m)
#     253 self.plot_t = process_results_for_plot(self._compare, tm_key="t")
#     256 # -- plot: -----------------------------------------------------------------------
#
# File ~/github/SIMBA/simba_performance_benchmark/performance_benchmark/results/_aggregate_plot_results.py:222, in SIMBAMemoryAugmentation.update(self, plot_m)
#     219 def update(self, plot_m):
#     221     ALL = {}
# --> 222     self.parse()
#     223     for i in self.MemDict.keys():
#     224         landmarks = self.MemDict[i]['landmarks']
#
# File ~/github/SIMBA/simba_performance_benchmark/performance_benchmark/results/_aggregate_plot_results.py:189, in SIMBAMemoryAugmentation.parse(self)
#     187 for k, v in self.simba_outs.items():
#     188     self.MemDict[k] = {}
# --> 189     self.MemDict[k]['landmarks'] = v['landmark_datetimes']
#     190     self.MemDict[k]['memory_df'] = v['memory_trace_df']
#
# KeyError: 'landmark_datetimes'

# %%
plot = pb.pr.PlotTimeMemory(results_path="./results/")
