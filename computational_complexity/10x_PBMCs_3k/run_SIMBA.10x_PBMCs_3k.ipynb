# %%
import performance_benchmark as pb
# Out:
# Available memory: 393 Gb
# Available vCPUs: 24

# %%
adata = pb.data.rna_10x_pbmcs_3k()
# Out:
# AnnData object with n_obs × n_vars = 2700 × 32738
#     obs: 'celltype'
#     var: 'gene_ids'

# %%
simba_outs = pb.methods.simba(
    adata,
    n_iters=4,
    dataset="rna_10x_PBMCs_3k",
)
# Out:
#   0%|          | 0/4 [00:00<?, ?it/s]
#  - Removed graph dir: /home/mvinyard/SIMBA/nbs_v3/./result_simba/pbg/rna_10x_PBMCs_3k
# Before filtering:
# 2700 cells, 32738 genes
# Filter genes based on min_n_cells
# After filtering out low-expressed genes:
# 2700 cells, 13714 genes
# before filtering:
# 2700 cells,  13714 genes
# filter cells based on min_n_genes
# after filtering out low-quality cells:
# 2700 cells,  13714 genes
# 2000 variable genes are selected.
# relation0: source: C, destination: G
# #edges: 138727
# relation1: source: C, destination: G
# #edges: 243405
# relation2: source: C, destination: G
# #edges: 82172
# relation3: source: C, destination: G
# #edges: 27876
# relation4: source: C, destination: G
# #edges: 17250
# Total number of edges: 509430
# Writing graph file "pbg_graph.txt" to "./result_simba/pbg/rna_10x_PBMCs_3k" ...
# **EDGE WRITE TIME: 6.228**
# Finished.
# Auto-estimated weight decay is 0.069558
# `.settings.pbg_params['wd']` has been updated to 0.069558
# Converting input data ...
# [2022-11-26 02:44:05.717574] Using the 5 relation types given in the config
# [2022-11-26 02:44:05.718877] Searching for the entities in the edge files...
# [2022-11-26 02:44:08.870612] Entity type C:
# [2022-11-26 02:44:08.872329] - Found 2700 entities
# [2022-11-26 02:44:08.873189] - Removing the ones with fewer than 1 occurrences...
# [2022-11-26 02:44:08.874606] - Left with 2700 entities
# [2022-11-26 02:44:08.875555] - Shuffling them...
# [2022-11-26 02:44:08.888532] Entity type G:
# [2022-11-26 02:44:08.889570] - Found 2000 entities
# [2022-11-26 02:44:08.890416] - Removing the ones with fewer than 1 occurrences...
# [2022-11-26 02:44:08.891708] - Left with 2000 entities
# [2022-11-26 02:44:08.892752] - Shuffling them...
# [2022-11-26 02:44:08.901808] Preparing counts and dictionaries for entities and relation types:
# [2022-11-26 02:44:08.904370] - Writing count of entity type C and partition 0
# [2022-11-26 02:44:08.911864] - Writing count of entity type G and partition 0
# [2022-11-26 02:44:08.917811] Preparing edge path ./result_simba/pbg/rna_10x_PBMCs_3k/input/edge, out of the edges found in result_simba/pbg/rna_10x_PBMCs_3k/pbg_graph.txt
# using fast version
# [2022-11-26 02:44:08.919272] Taking the fast train!
# [2022-11-26 02:44:12.130870] - Processed 100000 edges so far...
# [2022-11-26 02:44:15.303973] - Processed 200000 edges so far...
# [2022-11-26 02:44:18.429790] - Processed 300000 edges so far...
# [2022-11-26 02:44:21.671035] - Processed 400000 edges so far...
# [2022-11-26 02:44:24.851976] - Processed 500000 edges so far...
# [2022-11-26 02:44:26.651019] - Processed 509430 edges in total
# Starting training ...
# Finished
# Performing softmax transformation for query data 0;
# Successfully saved to: ./simba_benchmark_results/rna_10x_PBMCs_3k/benchmark_results.pkl
# Total size (bytes): 2238
#  - Removed graph dir: /home/mvinyard/SIMBA/nbs_v3/./result_simba/pbg/rna_10x_PBMCs_3k
# Before filtering:
# 2700 cells, 32738 genes
# Filter genes based on min_n_cells
# After filtering out low-expressed genes:
# 2700 cells, 13714 genes
# before filtering:
# 2700 cells,  13714 genes
# filter cells based on min_n_genes
# after filtering out low-quality cells:
# 2700 cells,  13714 genes
# 2000 variable genes are selected.
# relation0: source: C, destination: G
# #edges: 138727
# relation1: source: C, destination: G
# #edges: 243405
# relation2: source: C, destination: G
# #edges: 82172
# relation3: source: C, destination: G
# #edges: 27876
# relation4: source: C, destination: G
# #edges: 17250
# Total number of edges: 509430
# Writing graph file "pbg_graph.txt" to "./result_simba/pbg/rna_10x_PBMCs_3k" ...
# **EDGE WRITE TIME: 16.169**
# Finished.
# Auto-estimated weight decay is 0.069558
# `.settings.pbg_params['wd']` has been updated to 0.069558
# Converting input data ...
# [2022-11-26 02:47:31.471879] Using the 5 relation types given in the config
# [2022-11-26 02:47:31.475082] Searching for the entities in the edge files...
# [2022-11-26 02:47:41.232082] Entity type C:
# [2022-11-26 02:47:41.234393] - Found 2700 entities
# [2022-11-26 02:47:41.236534] - Removing the ones with fewer than 1 occurrences...
# [2022-11-26 02:47:41.239047] - Left with 2700 entities
# [2022-11-26 02:47:41.240781] - Shuffling them...
# [2022-11-26 02:47:41.261834] Entity type G:
# [2022-11-26 02:47:41.263979] - Found 2000 entities
# [2022-11-26 02:47:41.265705] - Removing the ones with fewer than 1 occurrences...
# [2022-11-26 02:47:41.268005] - Left with 2000 entities
# [2022-11-26 02:47:41.270022] - Shuffling them...
# [2022-11-26 02:47:41.288165] Preparing counts and dictionaries for entities and relation types:
# [2022-11-26 02:47:41.292069] - Writing count of entity type C and partition 0
# [2022-11-26 02:47:41.305914] - Writing count of entity type G and partition 0
# [2022-11-26 02:47:41.324174] Preparing edge path ./result_simba/pbg/rna_10x_PBMCs_3k/input/edge, out of the edges found in result_simba/pbg/rna_10x_PBMCs_3k/pbg_graph.txt
# using fast version
# [2022-11-26 02:47:41.342391] Taking the fast train!
# [2022-11-26 02:47:49.065631] - Processed 100000 edges so far...
# [2022-11-26 02:47:55.738327] - Processed 200000 edges so far...
# [2022-11-26 02:48:05.207882] - Processed 300000 edges so far...
# [2022-11-26 02:48:12.669368] - Processed 400000 edges so far...
# [2022-11-26 02:48:14.891368] - Processed 500000 edges so far...
# [2022-11-26 02:48:16.902518] - Processed 509430 edges in total
# Starting training ...
# Finished
# Performing softmax transformation for query data 0;
# Successfully saved to: ./simba_benchmark_results/rna_10x_PBMCs_3k_1/benchmark_results.pkl
# Total size (bytes): 2238
#  - Removed graph dir: /home/mvinyard/SIMBA/nbs_v3/./result_simba/pbg/rna_10x_PBMCs_3k
# Before filtering:
# 2700 cells, 32738 genes
# Filter genes based on min_n_cells
# After filtering out low-expressed genes:
# 2700 cells, 13714 genes
# before filtering:
# 2700 cells,  13714 genes
# filter cells based on min_n_genes
# after filtering out low-quality cells:
# 2700 cells,  13714 genes
# 2000 variable genes are selected.
# relation0: source: C, destination: G
# #edges: 138727
# relation1: source: C, destination: G
# #edges: 243405
# relation2: source: C, destination: G
# #edges: 82172
# relation3: source: C, destination: G
# #edges: 27876
# relation4: source: C, destination: G
# #edges: 17250
# Total number of edges: 509430
# Writing graph file "pbg_graph.txt" to "./result_simba/pbg/rna_10x_PBMCs_3k" ...
# **EDGE WRITE TIME: 15.643**
# Finished.
# Auto-estimated weight decay is 0.069558
# `.settings.pbg_params['wd']` has been updated to 0.069558
# Converting input data ...
# [2022-11-26 02:50:15.902511] Using the 5 relation types given in the config
# [2022-11-26 02:50:15.903765] Searching for the entities in the edge files...
# [2022-11-26 02:50:19.826320] Entity type C:
# [2022-11-26 02:50:19.827587] - Found 2700 entities
# [2022-11-26 02:50:19.828552] - Removing the ones with fewer than 1 occurrences...
# [2022-11-26 02:50:19.830074] - Left with 2700 entities
# [2022-11-26 02:50:19.830912] - Shuffling them...
# [2022-11-26 02:50:19.848714] Entity type G:
# [2022-11-26 02:50:19.849915] - Found 2000 entities
# [2022-11-26 02:50:19.850783] - Removing the ones with fewer than 1 occurrences...
# [2022-11-26 02:50:19.852061] - Left with 2000 entities
# [2022-11-26 02:50:19.852872] - Shuffling them...
# [2022-11-26 02:50:19.865889] Preparing counts and dictionaries for entities and relation types:
# [2022-11-26 02:50:19.867848] - Writing count of entity type C and partition 0
# [2022-11-26 02:50:19.876439] - Writing count of entity type G and partition 0
# [2022-11-26 02:50:19.883614] Preparing edge path ./result_simba/pbg/rna_10x_PBMCs_3k/input/edge, out of the edges found in result_simba/pbg/rna_10x_PBMCs_3k/pbg_graph.txt
# using fast version
# [2022-11-26 02:50:19.885212] Taking the fast train!
# [2022-11-26 02:50:22.340775] - Processed 100000 edges so far...
# [2022-11-26 02:50:24.641408] - Processed 200000 edges so far...
# [2022-11-26 02:50:26.884219] - Processed 300000 edges so far...
# [2022-11-26 02:50:29.162988] - Processed 400000 edges so far...
# [2022-11-26 02:50:31.335916] - Processed 500000 edges so far...
# [2022-11-26 02:50:34.816999] - Processed 509430 edges in total
# Starting training ...
# Finished
# Performing softmax transformation for query data 0;
# Successfully saved to: ./simba_benchmark_results/rna_10x_PBMCs_3k_2/benchmark_results.pkl
# Total size (bytes): 2238
#  - Removed graph dir: /home/mvinyard/SIMBA/nbs_v3/./result_simba/pbg/rna_10x_PBMCs_3k
# Before filtering:
# 2700 cells, 32738 genes
# Filter genes based on min_n_cells
# After filtering out low-expressed genes:
# 2700 cells, 13714 genes
# before filtering:
# 2700 cells,  13714 genes
# filter cells based on min_n_genes
# after filtering out low-quality cells:
# 2700 cells,  13714 genes
# 2000 variable genes are selected.
# relation0: source: C, destination: G
# #edges: 138727
# relation1: source: C, destination: G
# #edges: 243405
# relation2: source: C, destination: G
# #edges: 82172
# relation3: source: C, destination: G
# #edges: 27876
# relation4: source: C, destination: G
# #edges: 17250
# Total number of edges: 509430
# Writing graph file "pbg_graph.txt" to "./result_simba/pbg/rna_10x_PBMCs_3k" ...
# **EDGE WRITE TIME: 19.414**
# Finished.
# Auto-estimated weight decay is 0.069558
# `.settings.pbg_params['wd']` has been updated to 0.069558
# Converting input data ...
# [2022-11-26 02:53:07.615087] Using the 5 relation types given in the config
# [2022-11-26 02:53:07.618043] Searching for the entities in the edge files...
# [2022-11-26 02:53:20.395979] Entity type C:
# [2022-11-26 02:53:20.398964] - Found 2700 entities
# [2022-11-26 02:53:20.400760] - Removing the ones with fewer than 1 occurrences...
# [2022-11-26 02:53:20.403696] - Left with 2700 entities
# [2022-11-26 02:53:20.406101] - Shuffling them...
# [2022-11-26 02:53:20.447339] Entity type G:
# [2022-11-26 02:53:20.450347] - Found 2000 entities
# [2022-11-26 02:53:20.452090] - Removing the ones with fewer than 1 occurrences...
# [2022-11-26 02:53:20.454825] - Left with 2000 entities
# [2022-11-26 02:53:20.457147] - Shuffling them...
# [2022-11-26 02:53:20.486203] Preparing counts and dictionaries for entities and relation types:
# [2022-11-26 02:53:20.493126] - Writing count of entity type C and partition 0
# [2022-11-26 02:53:20.523214] - Writing count of entity type G and partition 0
# [2022-11-26 02:53:20.575008] Preparing edge path ./result_simba/pbg/rna_10x_PBMCs_3k/input/edge, out of the edges found in result_simba/pbg/rna_10x_PBMCs_3k/pbg_graph.txt
# using fast version
# [2022-11-26 02:53:20.578775] Taking the fast train!
# [2022-11-26 02:53:28.714558] - Processed 100000 edges so far...
# [2022-11-26 02:53:31.564673] - Processed 200000 edges so far...
# [2022-11-26 02:53:33.819902] - Processed 300000 edges so far...
# [2022-11-26 02:53:36.157069] - Processed 400000 edges so far...
# [2022-11-26 02:53:38.391747] - Processed 500000 edges so far...
# [2022-11-26 02:53:40.030992] - Processed 509430 edges in total
# Starting training ...
# Finished
# Performing softmax transformation for query data 0;
# Successfully saved to: ./simba_benchmark_results/rna_10x_PBMCs_3k_3/benchmark_results.pkl
# Total size (bytes): 2238
