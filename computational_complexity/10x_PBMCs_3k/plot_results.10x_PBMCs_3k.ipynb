# %%
# %load_ext nb_black

import performance_benchmark as pb
# Out:
# Available memory: 32 Gb
# Available vCPUs: 10

# %%
plot = pb.results.PlotTimeMemory(
    results_path="./results/",
    save=True,
    savename="./figs/compare_all_methods.time_memory.10x_PBMCs_3k.svg",
    figsize=0.3,
    wspace=0.4,
    legend_loc=(2.5, 0),
)
